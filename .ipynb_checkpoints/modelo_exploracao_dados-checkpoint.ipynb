# %% [markdown]
# # Exploração de Dados Públicos com Estatística Descritiva
# - Aluno: Pedro Yutaro Mont Morency Nakamura
# - Disciplina: Ciência de Dados
# - Data: Fervereiro de 2026

# %% [markdown]
# ## 1. Escolha do Dataset
# - Nome do dataset:
# - Link:
# - Órgão responsável:
# - Descrição:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Carregamento dos Dados

# %%
df = pd.read_csv('seu_arquivo.csv')
df.head()

# %% [markdown]
# ## 3. Descrição do Dataset
# - Número de registros e colunas:
# - Tipos de dados:
# - Descrição das variáveis importantes:

# %%
df.info()
df.describe()

# %% [markdown]
# ## 4. Estatísticas Descritivas

# %%
# Média
df.mean(numeric_only=True)

# Mediana
df.median(numeric_only=True)

# Moda
df.mode().iloc[0]

# %%
# Mínimo e Máximo
df.min(numeric_only=True)
df.max(numeric_only=True)

# %%
# Desvio padrão e variância
df.std(numeric_only=True)
df.var(numeric_only=True)

# %%
# Quartis e IQR
Q1 = df.quantile(0.25, numeric_only=True)
Q3 = df.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
Q1, Q3, IQR

# %%
# Valores ausentes
df.isnull().sum()

# %% [markdown]
# ## 5. Visualizações

# %%
# Histograma
df.hist(figsize=(10,8))
plt.show()

# %%
# Boxplot
df.plot(kind='box', subplots=True, layout=(3,3), figsize=(10,8))
plt.show()

# %%
# Gráfico de dispersão
sns.pairplot(df.select_dtypes(include=np.number))
plt.show()

# %% [markdown]
# ## 6. Análise e Comentários
# Descreva aqui os padrões observados, insights e possíveis irregularidades nos dados.
